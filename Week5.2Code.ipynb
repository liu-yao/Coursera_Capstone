# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.6.16          |           py36_1         149 KB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     ca-certificates-2019.6.16  |       hecc5488_0         145 KB  conda-forge
#     openssl-1.1.1c             |       h516909a_0         2.1 MB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.49-py_0         conda-forge
#     geopy:           1.20.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.5.15-0                   --> 2019.6.16-hecc5488_0 conda-forge
#     certifi:         2019.6.16-py36_0              --> 2019.6.16-py36_1     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1c-h7b6447c_1             --> 1.1.1c-h516909a_0    conda-forge
#
#
# Downloading and Extracting Packages
# certifi-2019.6.16    | 149 KB    | ##################################### | 100%
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# openssl-1.1.1c       | 2.1 MB    | ##################################### | 100%
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-3.1.0               |           py36_0         724 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         822 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  3.1.0-py36_0 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
#
# Downloading and Extracting Packages
# altair-3.1.0         | 724 KB    | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'Q2PGPTWBILUMLBNHJQ4LECO1N0HOTTERA1RHHSPXQ5AVFWSA' # your Foursquare ID
CLIENT_SECRET = 'AJV20ZGC5Y3AOU3PAKB1YCGIT2N1T2RZTBL0QSMR032HOC3E' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: Q2PGPTWBILUMLBNHJQ4LECO1N0HOTTERA1RHHSPXQ5AVFWSA
# CLIENT_SECRET:AJV20ZGC5Y3AOU3PAKB1YCGIT2N1T2RZTBL0QSMR032HOC3E

# %%
address = 'Singapore'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 1.3408528 103.878446863736

# %%
search_query = 'library'
radius = 100000
print(search_query + ' .... OK!')
# Out:
# library .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=Q2PGPTWBILUMLBNHJQ4LECO1N0HOTTERA1RHHSPXQ5AVFWSA&client_secret=AJV20ZGC5Y3AOU3PAKB1YCGIT2N1T2RZTBL0QSMR032HOC3E&ll=1.3408528,103.878446863736&v=20180604&query=library&radius=100000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d46d21d9241f80025066e2d'},
#  'response': {'venues': [{'id': '4cb974c8bac93704a07de47c',
#     'name': 'Serangoon Public Library',
#     'location': {'address': '#04-82/83 nex',
#      'crossStreet': '23 Serangoon Central',
#      'lat': 1.3503188006835691,
#      'lng': 103.87291759640893,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3503188006835691,
#        'lng': 103.87291759640893}],
#      'distance': 1220,
#      'postalCode': '556083',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['#04-82/83 nex (23 Serangoon Central)',
#       '556083',
#       'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d12f941735',
#       'name': 'Library',
#       'pluralName': 'Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '4b083651f964a520660623e3',
#     'name': 'National Library Building',
#     'location': {'address': '100 Victoria St.',
#      'lat': 1.297772867070058,
#      'lng': 103.85430399110722,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.297772867070058,
#        'lng': 103.85430399110722}],
#      'distance': 5496,
#      'postalCode': '188064',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['100 Victoria St.', '188064', 'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d12f941735',
#       'name': 'Library',
#       'pluralName': 'Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '4da64aa35da3e8486b8190b4',
#     'name': 'My Learning Suite (Library) @ Bartley Secondary School',
#     'location': {'address': '10 Jalan Bunga Rampai',
#      'lat': 1.3403750277641318,
#      'lng': 103.88397078395924,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3403750277641318,
#        'lng': 103.88397078395924}],
#      'distance': 617,
#      'postalCode': '538403',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['10 Jalan Bunga Rampai', '538403', 'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d1a7941735',
#       'name': 'College Library',
#       'pluralName': 'College Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '4b1bc985f964a5206afd23e3',
#     'name': 'Geylang East Public Library',
#     'location': {'address': '50 Geylang East Ave 1',
#      'lat': 1.3175293696242703,
#      'lng': 103.8858889945768,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3175293696242703,
#        'lng': 103.8858889945768}],
#      'distance': 2725,
#      'postalCode': '389777',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['50 Geylang East Ave 1', '389777', 'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d12f941735',
#       'name': 'Library',
#       'pluralName': 'Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '4eb8f460a17cab6128810da3',
#     'name': 'Bishan Public Library',
#     'location': {'address': '5 Bishan Place #01-01',
#      'lat': 1.3499050138382265,
#      'lng': 103.84894482394337,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3499050138382265,
#        'lng': 103.84894482394337}],
#      'distance': 3434,
#      'postalCode': '579841',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['5 Bishan Place #01-01', '579841', 'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d12f941735',
#       'name': 'Library',
#       'pluralName': 'Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '4b30898cf964a52016fa24e3',
#     'name': 'Toa Payoh Public Library',
#     'location': {'address': '6 Toa Payoh Central',
#      'lat': 1.3336109511477376,
#      'lng': 103.85043502575405,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3336109511477376,
#        'lng': 103.85043502575405}],
#      'distance': 3219,
#      'postalCode': '319191',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['6 Toa Payoh Central', '319191', 'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d12f941735',
#       'name': 'Library',
#       'pluralName': 'Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '4e26971b7d8b5ea72474f4ba',
#     'name': 'Library @ ZHSS.',
#     'location': {'lat': 1.3493070130513671,
#      'lng': 103.8696666034175,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3493070130513671,
#        'lng': 103.8696666034175}],
#      'distance': 1356,
#      'cc': 'SG',
#      'country': 'Singapore',
#      'formattedAddress': ['Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d1a7941735',
#       'name': 'College Library',
#       'pluralName': 'College Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '4cfcd1abee9cb60c652b97ad',
#     'name': 'Central Public Library',
#     'location': {'address': '#B1-01 National Library Building',
#      'crossStreet': '100 Victoria St.',
#      'lat': 1.297746182247215,
#      'lng': 103.85436104701142,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.297746182247215,
#        'lng': 103.85436104701142}],
#      'distance': 5496,
#      'postalCode': '188064',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['#B1-01 National Library Building (100 Victoria St.)',
#       '188064',
#       'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d12f941735',
#       'name': 'Library',
#       'pluralName': 'Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '4dcca31152b1f8915b6b03be',
#     'name': 'PLMGSS Library',
#     'location': {'address': '296 Lorong Ah Soo',
#      'lat': 1.3510806229788508,
#      'lng': 103.88548283364999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3510806229788508,
#        'lng': 103.88548283364999}],
#      'distance': 1381,
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['296 Lorong Ah Soo', 'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d1a7941735',
#       'name': 'College Library',
#       'pluralName': 'College Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '4ba2ee91f964a520672338e3',
#     'name': 'Li Ka Shing Library',
#     'location': {'address': '70 Stamford Rd.',
#      'crossStreet': 'Singapore Management University',
#      'lat': 1.2960498190507066,
#      'lng': 103.85027802650707,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.2960498190507066,
#        'lng': 103.85027802650707}],
#      'distance': 5890,
#      'postalCode': '178901',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['70 Stamford Rd. (Singapore Management University)',
#       '178901',
#       'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d1a7941735',
#       'name': 'College Library',
#       'pluralName': 'College Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '117993574'},
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '4b0a5375f964a520432323e3',
#     'name': 'Woodlands Regional Library',
#     'location': {'address': '900 South Woodlands Drive',
#      'crossStreet': 'Woodlands Civic Centre',
#      'lat': 1.4347296176057531,
#      'lng': 103.78729321780855,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.4347296176057531,
#        'lng': 103.78729321780855}],
#      'distance': 14564,
#      'postalCode': '730900',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['900 South Woodlands Drive (Woodlands Civic Centre)',
#       '730900',
#       'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d12f941735',
#       'name': 'Library',
#       'pluralName': 'Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '4ba45ce3f964a520a59838e3',
#     'name': 'Tampines Regional Library',
#     'location': {'address': '#02-01 Our Tampines Hub',
#      'crossStreet': '1 Tampines Walk',
#      'lat': 1.352608910457822,
#      'lng': 103.94072771072388,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.352608910457822,
#        'lng': 103.94072771072388}],
#      'distance': 7053,
#      'postalCode': '528523',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['#02-01 Our Tampines Hub (1 Tampines Walk)',
#       '528523',
#       'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d12f941735',
#       'name': 'Library',
#       'pluralName': 'Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '53cb7df8498ec6ddfb1429bc',
#     'name': 'Fivetwenty Library',
#     'location': {'address': '69 Ubi Road 1',
#      'crossStreet': '#05-19 Oxley Bizhub',
#      'lat': 1.330349228238954,
#      'lng': 103.8890280045427,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.330349228238954,
#        'lng': 103.8890280045427}],
#      'distance': 1659,
#      'postalCode': '408731',
#      'cc': 'SG',
#      'country': 'Singapore',
#      'formattedAddress': ['69 Ubi Road 1 (#05-19 Oxley Bizhub)',
#       '408731',
#       'Singapore']},
#     'categories': [{'id': '554a5e17498efabeda6cc559',
#       'name': 'Photography Studio',
#       'pluralName': 'Photography Studios',
#       'shortName': 'Photo Studio',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/camerastore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '4d9e897dd2946a31df583260',
#     'name': 'Library | Yuying Secondary School',
#     'location': {'address': '47 Hougang Aveune 1',
#      'lat': 1.3575425951740783,
#      'lng': 103.8908762577803,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3575425951740783,
#        'lng': 103.8908762577803}],
#      'distance': 2316,
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['47 Hougang Aveune 1', 'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d1a7941735',
#       'name': 'College Library',
#       'pluralName': 'College Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '4c3e844f6faac9b6836d0e76',
#     'name': "St Andrew's Secondary Library",
#     'location': {'lat': 1.330407951697515,
#      'lng': 103.86682406692938,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.330407951697515,
#        'lng': 103.86682406692938}],
#      'distance': 1739,
#      'cc': 'SG',
#      'country': 'Singapore',
#      'formattedAddress': ['Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d1a7941735',
#       'name': 'College Library',
#       'pluralName': 'College Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '4e1aab7be4cd49a7e3fe8121',
#     'name': 'Media Resource Library',
#     'location': {'address': '2 Mattar Rd',
#      'crossStreet': 'MacPherson Primary School',
#      'lat': 1.3249789735443878,
#      'lng': 103.8813328742981,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3249789735443878,
#        'lng': 103.8813328742981}],
#      'distance': 1796,
#      'postalCode': '387724',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['2 Mattar Rd (MacPherson Primary School)',
#       '387724',
#       'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d12f941735',
#       'name': 'Library',
#       'pluralName': 'Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '4b08e4e3f964a5202e1323e3',
#     'name': 'Ang Mo Kio Public Library',
#     'location': {'address': '4300 Ang Mo Kio Ave 6',
#      'lat': 1.3747690187462012,
#      'lng': 103.84546431333962,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3747690187462012,
#        'lng': 103.84546431333962}],
#      'distance': 5265,
#      'postalCode': '569842',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['4300 Ang Mo Kio Ave 6', '569842', 'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d12f941735',
#       'name': 'Library',
#       'pluralName': 'Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '4bde7e366198c9b6811a14ff',
#     'name': 'Bedok Public Library',
#     'location': {'address': '21 Bedok North St 1',
#      'lat': 1.3269489,
#      'lng': 103.93174,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3269489,
#        'lng': 103.93174}],
#      'distance': 6129,
#      'postalCode': '469659',
#      'cc': 'SG',
#      'neighborhood': 'Bedok',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['21 Bedok North St 1', '469659', 'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d12f941735',
#       'name': 'Library',
#       'pluralName': 'Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '4d97f70997d06ea8e1fa290b',
#     'name': 'library',
#     'location': {'address': 'bartley',
#      'lat': 1.340198102998803,
#      'lng': 103.88504677265811,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.340198102998803,
#        'lng': 103.88504677265811}],
#      'distance': 738,
#      'postalCode': '539787',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['bartley', '539787', 'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d12f941735',
#       'name': 'Library',
#       'pluralName': 'Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '4b1dc121f964a520dc1424e3',
#     'name': 'Cheng San Public Library',
#     'location': {'address': '#03-11 Hougang Mall',
#      'crossStreet': '90 Hougang Ave 10',
#      'lat': 1.3726186325681473,
#      'lng': 103.89378474311461,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3726186325681473,
#        'lng': 103.89378474311461}],
#      'distance': 3926,
#      'postalCode': '538766',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['#03-11 Hougang Mall (90 Hougang Ave 10)',
#       '538766',
#       'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d12f941735',
#       'name': 'Library',
#       'pluralName': 'Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '4d9ad6943f7854815555d2d1',
#     'name': 'Library @ BSS',
#     'location': {'address': "1 St Wilfred's Road",
#      'lat': 1.32384096005459,
#      'lng': 103.86349463746137,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.32384096005459,
#        'lng': 103.86349463746137}],
#      'distance': 2520,
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ["1 St Wilfred's Road", 'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'shortName': 'School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '4bcd7959fb84c9b6a10b223e',
#     'name': 'library@esplanade',
#     'location': {'address': '#03-01 Esplanade Mall',
#      'crossStreet': '8 Raffles Avenue',
#      'lat': 1.2900773839013877,
#      'lng': 103.85644658344783,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.2900773839013877,
#        'lng': 103.85644658344783}],
#      'distance': 6159,
#      'postalCode': '039802',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['#03-01 Esplanade Mall (8 Raffles Avenue)',
#       '039802',
#       'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d12f941735',
#       'name': 'Library',
#       'pluralName': 'Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '4b0bb6adf964a5202c3323e3',
#     'name': 'Marine Parade Public Library',
#     'location': {'address': '278 Marine Parade Road #01-02 Marine Parade Community Building',
#      'lat': 1.3052656529469284,
#      'lng': 103.9097479840158,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3052656529469284,
#        'lng': 103.9097479840158}],
#      'distance': 5275,
#      'postalCode': '449282',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['278 Marine Parade Road #01-02 Marine Parade Community Building',
#       '449282',
#       'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d12f941735',
#       'name': 'Library',
#       'pluralName': 'Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '4d54b276143ca0931250a7fc',
#     'name': "Saint Andrew's Junior College Library",
#     'location': {'address': '55 Potong Pasir Ave. 1',
#      'lat': 1.3320246516304608,
#      'lng': 103.86397107417386,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3320246516304608,
#        'lng': 103.86397107417386}],
#      'distance': 1887,
#      'postalCode': '358389',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['55 Potong Pasir Ave. 1', '358389', 'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d1a7941735',
#       'name': 'College Library',
#       'pluralName': 'College Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '4c7325e7376da093a27da8c6',
#     'name': 'Nanyang Junior College Library',
#     'location': {'address': '128 Serangoon Ave 3',
#      'lat': 1.3508455527306285,
#      'lng': 103.86547643091181,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3508455527306285,
#        'lng': 103.86547643091181}],
#      'distance': 1822,
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['128 Serangoon Ave 3', 'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d1a7941735',
#       'name': 'College Library',
#       'pluralName': 'College Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '4d6625026d86224b71898f81',
#     'name': 'Library @ Singapore Swimming Club',
#     'location': {'lat': 1.2975869774089437,
#      'lng': 103.8810240280969,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.2975869774089437,
#        'lng': 103.8810240280969}],
#      'distance': 4824,
#      'cc': 'SG',
#      'country': 'Singapore',
#      'formattedAddress': ['Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d12f941735',
#       'name': 'Library',
#       'pluralName': 'Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '4d4614501928a35daa82c970',
#     'name': 'Library | Kuo Chuan Presbyterian Secondary School',
#     'location': {'address': 'Kuo Chuan Presbyterian Secondary School',
#      'crossStreet': '10 Bishan St 13',
#      'lat': 1.3499591736135863,
#      'lng': 103.85526767199839,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3499591736135863,
#        'lng': 103.85526767199839}],
#      'distance': 2771,
#      'postalCode': '579795',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['Kuo Chuan Presbyterian Secondary School (10 Bishan St 13)',
#       '579795',
#       'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d1a7941735',
#       'name': 'College Library',
#       'pluralName': 'College Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '5bebc7963af98823a52cc62e',
#     'name': 'Whiskey Library @ The Vagabond Club',
#     'location': {'address': '39 Syed Alwi Road',
#      'crossStreet': "King George's Avenue",
#      'lat': 1.3069807351258018,
#      'lng': 103.85830879211426,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3069807351258018,
#        'lng': 103.85830879211426}],
#      'distance': 4386,
#      'postalCode': '207630',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'state': 'SG-01',
#      'country': 'Singapore',
#      'formattedAddress': ["39 Syed Alwi Road (King George's Avenue)",
#       '207630',
#       'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d122941735',
#       'name': 'Whisky Bar',
#       'pluralName': 'Whisky Bars',
#       'shortName': 'Whisky Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/whiskey_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '522903146'},
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '50d14ef0e4b04eb6f35e72d0',
#     'name': 'library@chinatown',
#     'location': {'address': '#04-12, Chinatown Point',
#      'crossStreet': '133 New Bridge Rd.',
#      'lat': 1.2849764621430568,
#      'lng': 103.84463655947532,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.2849764621430568,
#        'lng': 103.84463655947532}],
#      'distance': 7269,
#      'postalCode': '059413',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['#04-12, Chinatown Point (133 New Bridge Rd.)',
#       '059413',
#       'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d12f941735',
#       'name': 'Library',
#       'pluralName': 'Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564922397',
#     'hasPerk': False},
#    {'id': '4fd006f9e4b0297e315b7be7',
#     'name': 'AIS Primary Middle Library',
#     'location': {'address': 'Australian International School Singapore',
#      'crossStreet': '1 Lorong Chuan',
#      'lat': 1.3475522050851754,
#      'lng': 103.85950282679342,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3475522050851754,
#        'lng': 103.85950282679342}],
#      'distance': 2236,
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['Australian International School Singapore (1 Lorong Chuan)',
#       'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d1a7941735',
#       'name': 'College Library',
#       'pluralName': 'College Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564922397',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d12f941735', 'name': 'L...    False
# 1  [{'id': '4bf58dd8d48988d12f941735', 'name': 'L...    False
# 2  [{'id': '4bf58dd8d48988d1a7941735', 'name': 'C...    False
# 3  [{'id': '4bf58dd8d48988d12f941735', 'name': 'L...    False
# 4  [{'id': '4bf58dd8d48988d12f941735', 'name': 'L...    False
#
#                          id       location.address location.cc location.city  \
# 0  4cb974c8bac93704a07de47c          #04-82/83 nex          SG     Singapore
# 1  4b083651f964a520660623e3       100 Victoria St.          SG     Singapore
# 2  4da64aa35da3e8486b8190b4  10 Jalan Bunga Rampai          SG     Singapore
# 3  4b1bc985f964a5206afd23e3  50 Geylang East Ave 1          SG     Singapore
# 4  4eb8f460a17cab6128810da3  5 Bishan Place #01-01          SG     Singapore
#
#   location.country  location.crossStreet  location.distance  \
# 0        Singapore  23 Serangoon Central               1220
# 1        Singapore                   NaN               5496
# 2        Singapore                   NaN                617
# 3        Singapore                   NaN               2725
# 4        Singapore                   NaN               3434
#
#                            location.formattedAddress  \
# 0  [#04-82/83 nex (23 Serangoon Central), 556083,...
# 1              [100 Victoria St., 188064, Singapore]
# 2         [10 Jalan Bunga Rampai, 538403, Singapore]
# 3         [50 Geylang East Ave 1, 389777, Singapore]
# 4         [5 Bishan Place #01-01, 579841, Singapore]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 1.350318800683569...      1.350319
# 1  [{'label': 'display', 'lat': 1.297772867070058...      1.297773
# 2  [{'label': 'display', 'lat': 1.340375027764131...      1.340375
# 3  [{'label': 'display', 'lat': 1.317529369624270...      1.317529
# 4  [{'label': 'display', 'lat': 1.349905013838226...      1.349905
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    103.872918                   NaN              556083            NaN
# 1    103.854304                   NaN              188064            NaN
# 2    103.883971                   NaN              538403            NaN
# 3    103.885889                   NaN              389777            NaN
# 4    103.848945                   NaN              579841            NaN
#
#                                                 name    referralId  \
# 0                           Serangoon Public Library  v-1564922397
# 1                          National Library Building  v-1564922397
# 2  My Learning Suite (Library) @ Bartley Secondar...  v-1564922397
# 3                        Geylang East Public Library  v-1564922397
# 4                              Bishan Public Library  v-1564922397
#
#   venuePage.id
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name          categories  \
# 0                            Serangoon Public Library             Library
# 1                           National Library Building             Library
# 2   My Learning Suite (Library) @ Bartley Secondar...     College Library
# 3                         Geylang East Public Library             Library
# 4                               Bishan Public Library             Library
# 5                            Toa Payoh Public Library             Library
# 6                                     Library @ ZHSS.     College Library
# 7                              Central Public Library             Library
# 8                                      PLMGSS Library     College Library
# 9                                 Li Ka Shing Library     College Library
# 10                         Woodlands Regional Library             Library
# 11                          Tampines Regional Library             Library
# 12                                 Fivetwenty Library  Photography Studio
# 13                  Library | Yuying Secondary School     College Library
# 14                      St Andrew's Secondary Library     College Library
# 15                             Media Resource Library             Library
# 16                          Ang Mo Kio Public Library             Library
# 17                               Bedok Public Library             Library
# 18                                            library             Library
# 19                           Cheng San Public Library             Library
# 20                                      Library @ BSS              School
# 21                                  library@esplanade             Library
# 22                       Marine Parade Public Library             Library
# 23              Saint Andrew's Junior College Library     College Library
# 24                     Nanyang Junior College Library     College Library
# 25                  Library @ Singapore Swimming Club             Library
# 26  Library | Kuo Chuan Presbyterian Secondary School     College Library
# 27                Whiskey Library @ The Vagabond Club          Whisky Bar
# 28                                  library@chinatown             Library
# 29                         AIS Primary Middle Library     College Library
#
#                                               address  cc       city  \
# 0                                       #04-82/83 nex  SG  Singapore
# 1                                    100 Victoria St.  SG  Singapore
# 2                               10 Jalan Bunga Rampai  SG  Singapore
# 3                               50 Geylang East Ave 1  SG  Singapore
# 4                               5 Bishan Place #01-01  SG  Singapore
# 5                                 6 Toa Payoh Central  SG  Singapore
# 6                                                 NaN  SG        NaN
# 7                    #B1-01 National Library Building  SG  Singapore
# 8                                   296 Lorong Ah Soo  SG  Singapore
# 9                                     70 Stamford Rd.  SG  Singapore
# 10                          900 South Woodlands Drive  SG  Singapore
# 11                            #02-01 Our Tampines Hub  SG  Singapore
# 12                                      69 Ubi Road 1  SG        NaN
# 13                                47 Hougang Aveune 1  SG  Singapore
# 14                                                NaN  SG        NaN
# 15                                        2 Mattar Rd  SG  Singapore
# 16                              4300 Ang Mo Kio Ave 6  SG  Singapore
# 17                                21 Bedok North St 1  SG  Singapore
# 18                                            bartley  SG  Singapore
# 19                                #03-11 Hougang Mall  SG  Singapore
# 20                                1 St Wilfred's Road  SG  Singapore
# 21                              #03-01 Esplanade Mall  SG  Singapore
# 22  278 Marine Parade Road #01-02 Marine Parade Co...  SG  Singapore
# 23                             55 Potong Pasir Ave. 1  SG  Singapore
# 24                                128 Serangoon Ave 3  SG  Singapore
# 25                                                NaN  SG        NaN
# 26            Kuo Chuan Presbyterian Secondary School  SG  Singapore
# 27                                  39 Syed Alwi Road  SG  Singapore
# 28                            #04-12, Chinatown Point  SG  Singapore
# 29          Australian International School Singapore  SG  Singapore
#
#       country                      crossStreet  distance  \
# 0   Singapore             23 Serangoon Central      1220
# 1   Singapore                              NaN      5496
# 2   Singapore                              NaN       617
# 3   Singapore                              NaN      2725
# 4   Singapore                              NaN      3434
# 5   Singapore                              NaN      3219
# 6   Singapore                              NaN      1356
# 7   Singapore                 100 Victoria St.      5496
# 8   Singapore                              NaN      1381
# 9   Singapore  Singapore Management University      5890
# 10  Singapore           Woodlands Civic Centre     14564
# 11  Singapore                  1 Tampines Walk      7053
# 12  Singapore              #05-19 Oxley Bizhub      1659
# 13  Singapore                              NaN      2316
# 14  Singapore                              NaN      1739
# 15  Singapore        MacPherson Primary School      1796
# 16  Singapore                              NaN      5265
# 17  Singapore                              NaN      6129
# 18  Singapore                              NaN       738
# 19  Singapore                90 Hougang Ave 10      3926
# 20  Singapore                              NaN      2520
# 21  Singapore                 8 Raffles Avenue      6159
# 22  Singapore                              NaN      5275
# 23  Singapore                              NaN      1887
# 24  Singapore                              NaN      1822
# 25  Singapore                              NaN      4824
# 26  Singapore                  10 Bishan St 13      2771
# 27  Singapore             King George's Avenue      4386
# 28  Singapore               133 New Bridge Rd.      7269
# 29  Singapore                   1 Lorong Chuan      2236
#
#                                      formattedAddress  \
# 0   [#04-82/83 nex (23 Serangoon Central), 556083,...
# 1               [100 Victoria St., 188064, Singapore]
# 2          [10 Jalan Bunga Rampai, 538403, Singapore]
# 3          [50 Geylang East Ave 1, 389777, Singapore]
# 4          [5 Bishan Place #01-01, 579841, Singapore]
# 5            [6 Toa Payoh Central, 319191, Singapore]
# 6                                         [Singapore]
# 7   [#B1-01 National Library Building (100 Victori...
# 8                      [296 Lorong Ah Soo, Singapore]
# 9   [70 Stamford Rd. (Singapore Management Univers...
# 10  [900 South Woodlands Drive (Woodlands Civic Ce...
# 11  [#02-01 Our Tampines Hub (1 Tampines Walk), 52...
# 12  [69 Ubi Road 1 (#05-19 Oxley Bizhub), 408731, ...
# 13                   [47 Hougang Aveune 1, Singapore]
# 14                                        [Singapore]
# 15  [2 Mattar Rd (MacPherson Primary School), 3877...
# 16         [4300 Ang Mo Kio Ave 6, 569842, Singapore]
# 17           [21 Bedok North St 1, 469659, Singapore]
# 18                       [bartley, 539787, Singapore]
# 19  [#03-11 Hougang Mall (90 Hougang Ave 10), 5387...
# 20                   [1 St Wilfred's Road, Singapore]
# 21  [#03-01 Esplanade Mall (8 Raffles Avenue), 039...
# 22  [278 Marine Parade Road #01-02 Marine Parade C...
# 23        [55 Potong Pasir Ave. 1, 358389, Singapore]
# 24                   [128 Serangoon Ave 3, Singapore]
# 25                                        [Singapore]
# 26  [Kuo Chuan Presbyterian Secondary School (10 B...
# 27  [39 Syed Alwi Road (King George's Avenue), 207...
# 28  [#04-12, Chinatown Point (133 New Bridge Rd.),...
# 29  [Australian International School Singapore (1 ...
#
#                                        labeledLatLngs       lat         lng  \
# 0   [{'label': 'display', 'lat': 1.350318800683569...  1.350319  103.872918
# 1   [{'label': 'display', 'lat': 1.297772867070058...  1.297773  103.854304
# 2   [{'label': 'display', 'lat': 1.340375027764131...  1.340375  103.883971
# 3   [{'label': 'display', 'lat': 1.317529369624270...  1.317529  103.885889
# 4   [{'label': 'display', 'lat': 1.349905013838226...  1.349905  103.848945
# 5   [{'label': 'display', 'lat': 1.333610951147737...  1.333611  103.850435
# 6   [{'label': 'display', 'lat': 1.349307013051367...  1.349307  103.869667
# 7   [{'label': 'display', 'lat': 1.297746182247215...  1.297746  103.854361
# 8   [{'label': 'display', 'lat': 1.351080622978850...  1.351081  103.885483
# 9   [{'label': 'display', 'lat': 1.296049819050706...  1.296050  103.850278
# 10  [{'label': 'display', 'lat': 1.434729617605753...  1.434730  103.787293
# 11  [{'label': 'display', 'lat': 1.352608910457822...  1.352609  103.940728
# 12  [{'label': 'display', 'lat': 1.330349228238954...  1.330349  103.889028
# 13  [{'label': 'display', 'lat': 1.357542595174078...  1.357543  103.890876
# 14  [{'label': 'display', 'lat': 1.330407951697515...  1.330408  103.866824
# 15  [{'label': 'display', 'lat': 1.324978973544387...  1.324979  103.881333
# 16  [{'label': 'display', 'lat': 1.374769018746201...  1.374769  103.845464
# 17  [{'label': 'display', 'lat': 1.3269489, 'lng':...  1.326949  103.931740
# 18  [{'label': 'display', 'lat': 1.340198102998803...  1.340198  103.885047
# 19  [{'label': 'display', 'lat': 1.372618632568147...  1.372619  103.893785
# 20  [{'label': 'display', 'lat': 1.32384096005459,...  1.323841  103.863495
# 21  [{'label': 'display', 'lat': 1.290077383901387...  1.290077  103.856447
# 22  [{'label': 'display', 'lat': 1.305265652946928...  1.305266  103.909748
# 23  [{'label': 'display', 'lat': 1.332024651630460...  1.332025  103.863971
# 24  [{'label': 'display', 'lat': 1.350845552730628...  1.350846  103.865476
# 25  [{'label': 'display', 'lat': 1.297586977408943...  1.297587  103.881024
# 26  [{'label': 'display', 'lat': 1.349959173613586...  1.349959  103.855268
# 27  [{'label': 'display', 'lat': 1.306980735125801...  1.306981  103.858309
# 28  [{'label': 'display', 'lat': 1.284976462143056...  1.284976  103.844637
# 29  [{'label': 'display', 'lat': 1.347552205085175...  1.347552  103.859503
#
#    neighborhood postalCode  state                        id
# 0           NaN     556083    NaN  4cb974c8bac93704a07de47c
# 1           NaN     188064    NaN  4b083651f964a520660623e3
# 2           NaN     538403    NaN  4da64aa35da3e8486b8190b4
# 3           NaN     389777    NaN  4b1bc985f964a5206afd23e3
# 4           NaN     579841    NaN  4eb8f460a17cab6128810da3
# 5           NaN     319191    NaN  4b30898cf964a52016fa24e3
# 6           NaN        NaN    NaN  4e26971b7d8b5ea72474f4ba
# 7           NaN     188064    NaN  4cfcd1abee9cb60c652b97ad
# 8           NaN        NaN    NaN  4dcca31152b1f8915b6b03be
# 9           NaN     178901    NaN  4ba2ee91f964a520672338e3
# 10          NaN     730900    NaN  4b0a5375f964a520432323e3
# 11          NaN     528523    NaN  4ba45ce3f964a520a59838e3
# 12          NaN     408731    NaN  53cb7df8498ec6ddfb1429bc
# 13          NaN        NaN    NaN  4d9e897dd2946a31df583260
# 14          NaN        NaN    NaN  4c3e844f6faac9b6836d0e76
# 15          NaN     387724    NaN  4e1aab7be4cd49a7e3fe8121
# 16          NaN     569842    NaN  4b08e4e3f964a5202e1323e3
# 17        Bedok     469659    NaN  4bde7e366198c9b6811a14ff
# 18          NaN     539787    NaN  4d97f70997d06ea8e1fa290b
# 19          NaN     538766    NaN  4b1dc121f964a520dc1424e3
# 20          NaN        NaN    NaN  4d9ad6943f7854815555d2d1
# 21          NaN     039802    NaN  4bcd7959fb84c9b6a10b223e
# 22          NaN     449282    NaN  4b0bb6adf964a5202c3323e3
# 23          NaN     358389    NaN  4d54b276143ca0931250a7fc
# 24          NaN        NaN    NaN  4c7325e7376da093a27da8c6
# 25          NaN        NaN    NaN  4d6625026d86224b71898f81
# 26          NaN     579795    NaN  4d4614501928a35daa82c970
# 27          NaN     207630  SG-01  5bebc7963af98823a52cc62e
# 28          NaN     059413    NaN  50d14ef0e4b04eb6f35e72d0
# 29          NaN        NaN    NaN  4fd006f9e4b0297e315b7be7

# %%
dataframe_filtered.name
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Singapore',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the liraries as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
